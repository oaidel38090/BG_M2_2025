# %% [markdown]
# # Spark introduction

# %% [markdown]
# # Pré-requis

# %% [markdown]
# Dans une infrastructure BIG DATA, on couple souvent Spark et HDFS : Spark pour le traitement des données et HDFS pour le stockage de données.
#
# Dans l'environnement Docker, nous utiliserons notre cluster HDFS abordé précédemment pour effectuer des traitements via un cluster Spark.
#
# Notre cluster Spark sera constitué de 2 workers avec 1 cpu et 1Go de RAM pour ne pas trop charger votre machine.

# %% [markdown]
# ![image.png](attachment:4c72565d-5ddf-4962-9dde-8feedc33db1c.png)

# %% [markdown]
# Pour les TP nous utiliserons différents jeux de données :
# * appl_stock.csv : Des données relatives au prix de la pomme en bourse.
# * sales_info.csv : Une liste des ventes réalisées entre entreprises.
# * wash_dc_crime_incidents_2013 : Liste des crimes répertoriée à Washington en 2013
#
# Ces 3 jeux de données sont inclus dans le container jupyter.
# Merci de bien vouloir démarrer votre cluster HDFS et de copier les jeux de données que vous utiliserez pour les TP SPARK.

# %% [markdown]
# Démarrer le cluster HDFS :

# %% [raw]
# cd /chemin/du/cours/bigdata/docker
# docker start namenode datanode1 datanode2

# %% [markdown]
# Copier des fichiers de jeux de données en exécutant la cellule suivante :

# %%
# !$HADOOP_HOME/bin/hdfs dfs -mkdir -p /data/tpspark
# !$HADOOP_HOME/bin/hdfs dfs -put /home/jovyan/data/sales_info.csv /data/tpspark/
# !$HADOOP_HOME/bin/hdfs dfs -put /home/jovyan/data/wash_dc_crime_incidents_2013.csv /data/tpspark/
# !$HADOOP_HOME/bin/hdfs dfs -put /home/jovyan/data/appl_stock.csv /data/tpspark/
# Out:
# put: `/data/tpspark/sales_info.csv': File exists
# put: `/data/tpspark/wash_dc_crime_incidents_2013.csv': File exists
# put: `/data/tpspark/appl_stock.csv': File exists

# %% [markdown]
# On vérifie que les fichiers sont bien dans hdfs :

# %%
# !$HADOOP_HOME/bin/hdfs dfs -ls /data/tpspark
# Out:
# Found 3 items
# -rw-r--r--   1 jovyan supergroup     143130 2026-01-11 19:47 /data/tpspark/appl_stock.csv
# -rw-r--r--   1 jovyan supergroup        192 2026-01-11 19:47 /data/tpspark/sales_info.csv
# -rw-r--r--   1 jovyan supergroup    7942203 2026-01-11 19:47 /data/tpspark/wash_dc_crime_incidents_2013.csv

# %% [markdown]
# On peut à présent instancier notre cluster Spark

# %% [raw]
# cd /chemin/du/cours/bigdata/docker
# docker compose up -d smaster sworker1 sworker2

# %% [markdown]
# Vérifiez que les containers smaster, sworker1 et sworker2 sont démarrés :

# %% [raw]
# docker ps

# %% [markdown]
# Dans la configuration actuelle de Spark, nous utilisons le gestionnaire de ressources ( Spark Standalone ) fournit nativement avec Spark.

# %% [markdown]
# Une fois Spark démarré, vous aurez accés à l'interface du cluster Spark.

# %% [markdown]
# [http://DOCKER_HOST:8080](http://127.0.0.1:8080)

# %% [markdown]
# ![Capture%20d%E2%80%99e%CC%81cran%202022-03-13%20a%CC%80%2012.18.41.png](attachment:Capture%20d%E2%80%99e%CC%81cran%202022-03-13%20a%CC%80%2012.18.41.png)

# %% [markdown]
# Dans l'interface graphique de Spark, nous trouverons une mine d'information sur la gestion des tâches et les plans d'exécution de Spark pour chaque traitement. Nous ne couvrirons pas dans ce cours l'interface mais nous allons plus nous intéresser à la soumission de tâche sur Spark.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Attention, certains liens ne fonctionneront pas dans un environnement sous docker, vous devrez modifier manuellement les URLS des liens par 127.0.0.1
# </div>

# %% [markdown]
# Avec Spark, il est possible de soumettre du code SCALA ou PYTHON de plusieurs manières :
# * avec l'interpreteur spark pour du code en SCALA
# * avec l'interpreteur pyspark pour du code en python
# * par soumission de jobs (spark-submit)
#
# Dans les TP, nous nous focaliserons uniquement sur pyspark et la soumission de jobs.
#
# ## Connexion à Spark via pyspark
#
# Ouvrez un terminal sur jupyterlab :

# %% [raw]
# docker exec -it jupyter bash
# (base) jovyan@2bad2b16c95b:~$

# %% [markdown]
# Utiliser l'interpreteur pyspark pour vous connecter à votre cluster spark:

# %% [raw]
# (base) jovyan@2bad2b16c95b:~$ pyspark --master spark://smaster:7077

# %% [markdown]
# Pour confirmer que vous êtes bien connecté, lancez la commande suivante :

# %% [raw]
# >>> sc.master
# 'spark://smaster:7077'

# %% [markdown]
# La variable sc est par défaut celle utilisée par pyspark pour identifier l'objet de connexion à notre cluster Spark.

# %% [markdown]
# Vous pouvez à présent lancer un petit code qui traite une liste de valeur numérique et ajoute1 à chaque valeur :

# %% [raw]
# nums= sc.parallelize([1,2,3,4,5])
# r = nums.map( lambda x : x + 1)
# r.collect()

# %% [markdown]
# Le driver Spark est le composant dont le rôle est d'optimiser la parallelisation des traitements sur l'ensemble des workers. L'avancement de tous les jobs ainsi que le niveau de parallélisme sont visibles sur l'interface graphique fournit avec le driver. Pour consulter ces informations vous pouvez consulter l'url suivante : [http://dockerhost:4040](http://127.0.0.1:4040)
#
# Rappel, le driver converti un traitement en tâche lesquelles sont ensuite transmises aux différents workers. Si vous ne soumettez pas de job, l'url n'affichera rien.

# %% [markdown]
# ![Capture d’écran 2022-03-17 à 18.04.16.png](attachment:8977f6bb-919a-4dec-9ef8-888a74e3f6a4.png)

# %% [markdown]
# ## Comment soumettre un job Spark

# %% [markdown]
# Tout au long des TPs, vous allez dans la plupart des cas utiliser le notebook comme interface.
# Cependant, il faut savoir qu'il est possible de soumettre des jobs/ applications Spark via la commande spark-submit.
#
# Spark-submit prend de nombreuses options lesquelles définissent l'environnement d'exécution du programme spark :
# * le nombre d'executeur
# * le nombre de CPU / RAM par executeur
# * l'emplacement du driver
#     * Le driver est contenairisé et dans ce cas le programme continue de s'exéuter même si le client qui a soumis le programme n'est plus joignable (mode cluster)
#     * Le driver est sur une machine (mode client) qui communique avec le cluster et doit être accessible tout au long du traitement (mode par défaut).

# %% [markdown]
# Nous allons utiliser un petit programme Spark qui va compter le nombre de mots dans le fichier suivant : /datasets/wash_dc_crime_incidents_2013.csv

# %%
with open('spark_program.py', 'w') as fh:
        fh.write("""#!/usr/bin/env python
from pyspark import SparkContext
from operator import add
# On peut définir les ressources à allouer au programme via le SparkContext
# Le SparkContext peut être configuré via les options de spark-submit soit dans le programme  
sc = SparkContext("spark://smaster:7077", "MonProgramme")
myRdd =  sc.textFile("/data/tpspark/wash_dc_crime_incidents_2013.csv")

result = myRdd.map(lambda x : ("rowcount",1)).reduceByKey(add).collect()
for r in result:
    print(r)
""")
# !chmod a+x spark_program.py

# %% [markdown]
# On peut à présent soumettre notre programme :
#
# Pour afficher les détails de la répartition des tâches, le niveau des traces a été mis à INFO et vous montrera le nombre de tâches distribuées soumis sur les workers.
# Le résultat est quelque peu noyer sous les traces mais vous devriez voir apparaître le résultat suivant : ('rowcount', 35898)

# %%
# !spark-submit --name 'Mon Programme Spark' spark_program.py
# Out:
# 2026-02-05 20:23:21,434 INFO spark.SparkContext: Running Spark version 3.2.1
# 2026-02-05 20:23:21,707 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-02-05 20:23:21,861 INFO resource.ResourceUtils: ==============================================================
# 2026-02-05 20:23:21,861 INFO resource.ResourceUtils: No custom resources configured for spark.driver.
# 2026-02-05 20:23:21,861 INFO resource.ResourceUtils: ==============================================================
# 2026-02-05 20:23:21,861 INFO spark.SparkContext: Submitted application: MonProgramme
# 2026-02-05 20:23:21,894 INFO resource.ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 2026-02-05 20:23:21,906 INFO resource.ResourceProfile: Limiting resource is cpu
# 2026-02-05 20:23:21,907 INFO resource.ResourceProfileManager: Added ResourceProfile id: 0
# 2026-02-05 20:23:21,975 INFO spark.SecurityManager: Changing view acls to: jovyan
# 2026-02-05 20:23:21,976 INFO spark.SecurityManager: Changing modify acls to: jovyan
# 2026-02-05 20:23:21,976 INFO spark.SecurityManager: Changing view acls groups to:
# 2026-02-05 20:23:21,979 INFO spark.SecurityManager: Changing modify acls groups to:
# 2026-02-05 20:23:21,980 INFO spark.SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(jovyan); groups with view permissions: Set(); users  with modify permissions: Set(jovyan); groups with modify permissions: Set()
# 2026-02-05 20:23:22,268 INFO util.Utils: Successfully started service 'sparkDriver' on port 43279.
# 2026-02-05 20:23:22,304 INFO spark.SparkEnv: Registering MapOutputTracker
# 2026-02-05 20:23:22,342 INFO spark.SparkEnv: Registering BlockManagerMaster
# 2026-02-05 20:23:22,379 INFO storage.BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 2026-02-05 20:23:22,380 INFO storage.BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 2026-02-05 20:23:22,385 INFO spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 2026-02-05 20:23:22,406 INFO storage.DiskBlockManager: Created local directory at /tmp/blockmgr-025771bc-c749-45fe-a25b-c35fd51fe67e
# 2026-02-05 20:23:22,428 INFO memory.MemoryStore: MemoryStore started with capacity 366.3 MiB
# 2026-02-05 20:23:22,453 INFO spark.SparkEnv: Registering OutputCommitCoordinator
# 2026-02-05 20:23:22,545 INFO util.log: Logging initialized @3935ms to org.sparkproject.jetty.util.log.Slf4jLog
# 2026-02-05 20:23:22,614 INFO server.Server: jetty-9.4.43.v20210629; built: 2021-06-30T11:07:22.254Z; git: 526006ecfa3af7f1a27ef3a288e2bef7ea9dd7e8; jvm 1.8.0_382-8u382-ga-1~20.04.1-b05
# 2026-02-05 20:23:22,664 INFO server.Server: Started @4055ms
# 2026-02-05 20:23:22,708 WARN util.Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 2026-02-05 20:23:22,725 INFO server.AbstractConnector: Started ServerConnector@b327680{HTTP/1.1, (http/1.1)}{0.0.0.0:4041}
# 2026-02-05 20:23:22,725 INFO util.Utils: Successfully started service 'SparkUI' on port 4041.
# 2026-02-05 20:23:22,769 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@5fc661b0{/jobs,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,773 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@214297b9{/jobs/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,774 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@351ffb94{/jobs/job,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,778 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@3badb9e7{/jobs/job/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,779 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@5b270347{/stages,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,780 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@5d9f79f3{/stages/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,780 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@79490d42{/stages/stage,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,783 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1bf84fca{/stages/stage/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,785 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@8bb5c76{/stages/pool,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,786 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@28513269{/stages/pool/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,787 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1bdf734{/storage,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,789 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@247820f3{/storage/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,790 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@23029ef3{/storage/rdd,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,791 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1f989b4b{/storage/rdd/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,792 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@23180cc7{/environment,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,792 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@10f14b42{/environment/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,793 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@30181bc3{/executors,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,794 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@2751e4b9{/executors/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,795 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@2e41aad6{/executors/threadDump,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,797 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@3bd87e04{/executors/threadDump/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,813 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@7d581a92{/static,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,815 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@1ce3b3c3{/,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,816 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@3e34ca97{/api,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,818 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@ab477db{/jobs/job/kill,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,820 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@d5ad413{/stages/stage/kill,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:22,826 INFO ui.SparkUI: Bound SparkUI to 0.0.0.0, and started at http://a3b2f2c7c7c5:4041
# 2026-02-05 20:23:23,238 INFO client.StandaloneAppClient$ClientEndpoint: Connecting to master spark://smaster:7077...
# 2026-02-05 20:23:23,313 INFO client.TransportClientFactory: Successfully created connection to smaster/172.22.0.6:7077 after 44 ms (0 ms spent in bootstraps)
# 2026-02-05 20:23:23,486 INFO cluster.StandaloneSchedulerBackend: Connected to Spark cluster with app ID app-20260205202323-0001
# 2026-02-05 20:23:23,497 INFO util.Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 44887.
# 2026-02-05 20:23:23,497 INFO netty.NettyBlockTransferService: Server created on a3b2f2c7c7c5:44887
# 2026-02-05 20:23:23,500 INFO storage.BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 2026-02-05 20:23:23,509 INFO storage.BlockManagerMaster: Registering BlockManager BlockManagerId(driver, a3b2f2c7c7c5, 44887, None)
# 2026-02-05 20:23:23,513 INFO storage.BlockManagerMasterEndpoint: Registering block manager a3b2f2c7c7c5:44887 with 366.3 MiB RAM, BlockManagerId(driver, a3b2f2c7c7c5, 44887, None)
# 2026-02-05 20:23:23,516 INFO storage.BlockManagerMaster: Registered BlockManager BlockManagerId(driver, a3b2f2c7c7c5, 44887, None)
# 2026-02-05 20:23:23,517 INFO storage.BlockManager: Initialized BlockManager: BlockManagerId(driver, a3b2f2c7c7c5, 44887, None)
# 2026-02-05 20:23:23,699 INFO handler.ContextHandler: Started o.s.j.s.ServletContextHandler@350aea59{/metrics/json,null,AVAILABLE,@Spark}
# 2026-02-05 20:23:23,885 INFO cluster.StandaloneSchedulerBackend: SchedulerBackend is ready for scheduling beginning after reached minRegisteredResourcesRatio: 0.0
# 2026-02-05 20:23:24,574 INFO memory.MemoryStore: Block broadcast_0 stored as values in memory (estimated size 354.1 KiB, free 366.0 MiB)
# 2026-02-05 20:23:24,727 INFO memory.MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 32.1 KiB, free 365.9 MiB)
# 2026-02-05 20:23:24,731 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on a3b2f2c7c7c5:44887 (size: 32.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:24,736 INFO spark.SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 2026-02-05 20:23:25,683 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-02-05 20:23:26,009 INFO spark.SparkContext: Starting job: collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9
# 2026-02-05 20:23:26,038 INFO scheduler.DAGScheduler: Registering RDD 3 (reduceByKey at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) as input to shuffle 0
# 2026-02-05 20:23:26,042 INFO scheduler.DAGScheduler: Got job 0 (collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) with 2 output partitions
# 2026-02-05 20:23:26,043 INFO scheduler.DAGScheduler: Final stage: ResultStage 1 (collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9)
# 2026-02-05 20:23:26,043 INFO scheduler.DAGScheduler: Parents of final stage: List(ShuffleMapStage 0)
# 2026-02-05 20:23:26,048 INFO scheduler.DAGScheduler: Missing parents: List(ShuffleMapStage 0)
# 2026-02-05 20:23:26,057 INFO scheduler.DAGScheduler: Submitting ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9), which has no missing parents
# 2026-02-05 20:23:26,236 INFO memory.MemoryStore: Block broadcast_1 stored as values in memory (estimated size 11.5 KiB, free 365.9 MiB)
# 2026-02-05 20:23:26,244 INFO memory.MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 7.1 KiB, free 365.9 MiB)
# 2026-02-05 20:23:26,245 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on a3b2f2c7c7c5:44887 (size: 7.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:26,246 INFO spark.SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1478
# 2026-02-05 20:23:26,268 INFO scheduler.DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) (first 15 tasks are for partitions Vector(0, 1))
# 2026-02-05 20:23:26,270 INFO scheduler.TaskSchedulerImpl: Adding task set 0.0 with 2 tasks resource profile 0
# 2026-02-05 20:23:41,299 WARN scheduler.TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 2026-02-05 20:23:51,072 INFO client.StandaloneAppClient$ClientEndpoint: Executor added: app-20260205202323-0001/0 on worker-20260205201908-172.22.0.8-37589 (172.22.0.8:37589) with 1 core(s)
# 2026-02-05 20:23:51,075 INFO cluster.StandaloneSchedulerBackend: Granted executor ID app-20260205202323-0001/0 on hostPort 172.22.0.8:37589 with 1 core(s), 1024.0 MiB RAM
# 2026-02-05 20:23:51,076 INFO client.StandaloneAppClient$ClientEndpoint: Executor added: app-20260205202323-0001/1 on worker-20260205201908-172.22.0.7-41393 (172.22.0.7:41393) with 1 core(s)
# 2026-02-05 20:23:51,078 INFO cluster.StandaloneSchedulerBackend: Granted executor ID app-20260205202323-0001/1 on hostPort 172.22.0.7:41393 with 1 core(s), 1024.0 MiB RAM
# 2026-02-05 20:23:51,312 INFO client.StandaloneAppClient$ClientEndpoint: Executor updated: app-20260205202323-0001/0 is now RUNNING
# 2026-02-05 20:23:51,313 INFO client.StandaloneAppClient$ClientEndpoint: Executor updated: app-20260205202323-0001/1 is now RUNNING
# 2026-02-05 20:23:54,823 INFO cluster.CoarseGrainedSchedulerBackend$DriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.22.0.7:58422) with ID 1,  ResourceProfileId 0
# 2026-02-05 20:23:54,832 INFO cluster.CoarseGrainedSchedulerBackend$DriverEndpoint: Registered executor NettyRpcEndpointRef(spark-client://Executor) (172.22.0.8:44606) with ID 0,  ResourceProfileId 0
# 2026-02-05 20:23:55,086 INFO storage.BlockManagerMasterEndpoint: Registering block manager 172.22.0.7:33079 with 366.3 MiB RAM, BlockManagerId(1, 172.22.0.7, 33079, None)
# 2026-02-05 20:23:55,095 INFO storage.BlockManagerMasterEndpoint: Registering block manager 172.22.0.8:43391 with 366.3 MiB RAM, BlockManagerId(0, 172.22.0.8, 43391, None)
# 2026-02-05 20:23:55,185 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (172.22.0.7, executor 1, partition 0, ANY, 4528 bytes) taskResourceAssignments Map()
# 2026-02-05 20:23:55,202 INFO scheduler.TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1) (172.22.0.8, executor 0, partition 1, ANY, 4528 bytes) taskResourceAssignments Map()
# 2026-02-05 20:23:55,752 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on 172.22.0.7:33079 (size: 7.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:55,764 INFO storage.BlockManagerInfo: Added broadcast_1_piece0 in memory on 172.22.0.8:43391 (size: 7.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:56,682 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on 172.22.0.7:33079 (size: 32.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:56,692 INFO storage.BlockManagerInfo: Added broadcast_0_piece0 in memory on 172.22.0.8:43391 (size: 32.1 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:59,231 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 4071 ms on 172.22.0.7 (executor 1) (1/2)
# 2026-02-05 20:23:59,243 INFO python.PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 37879
# 2026-02-05 20:23:59,423 INFO scheduler.TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 4222 ms on 172.22.0.8 (executor 0) (2/2)
# 2026-02-05 20:23:59,427 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 2026-02-05 20:23:59,430 INFO scheduler.DAGScheduler: ShuffleMapStage 0 (reduceByKey at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) finished in 33.260 s
# 2026-02-05 20:23:59,431 INFO scheduler.DAGScheduler: looking for newly runnable stages
# 2026-02-05 20:23:59,431 INFO scheduler.DAGScheduler: running: Set()
# 2026-02-05 20:23:59,431 INFO scheduler.DAGScheduler: waiting: Set(ResultStage 1)
# 2026-02-05 20:23:59,431 INFO scheduler.DAGScheduler: failed: Set()
# 2026-02-05 20:23:59,439 INFO scheduler.DAGScheduler: Submitting ResultStage 1 (PythonRDD[6] at collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9), which has no missing parents
# 2026-02-05 20:23:59,462 INFO memory.MemoryStore: Block broadcast_2 stored as values in memory (estimated size 9.1 KiB, free 365.9 MiB)
# 2026-02-05 20:23:59,470 INFO memory.MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 5.4 KiB, free 365.9 MiB)
# 2026-02-05 20:23:59,473 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on a3b2f2c7c7c5:44887 (size: 5.4 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:59,476 INFO spark.SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1478
# 2026-02-05 20:23:59,483 INFO scheduler.DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (PythonRDD[6] at collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) (first 15 tasks are for partitions Vector(0, 1))
# 2026-02-05 20:23:59,483 INFO scheduler.TaskSchedulerImpl: Adding task set 1.0 with 2 tasks resource profile 0
# 2026-02-05 20:23:59,492 INFO scheduler.TaskSetManager: Starting task 0.0 in stage 1.0 (TID 2) (172.22.0.7, executor 1, partition 0, NODE_LOCAL, 4275 bytes) taskResourceAssignments Map()
# 2026-02-05 20:23:59,493 INFO scheduler.TaskSetManager: Starting task 1.0 in stage 1.0 (TID 3) (172.22.0.8, executor 0, partition 1, PROCESS_LOCAL, 4275 bytes) taskResourceAssignments Map()
# 2026-02-05 20:23:59,607 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on 172.22.0.7:33079 (size: 5.4 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:59,620 INFO storage.BlockManagerInfo: Added broadcast_2_piece0 in memory on 172.22.0.8:43391 (size: 5.4 KiB, free: 366.3 MiB)
# 2026-02-05 20:23:59,790 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 0 to 172.22.0.8:44606
# 2026-02-05 20:23:59,790 INFO spark.MapOutputTrackerMasterEndpoint: Asked to send map output locations for shuffle 0 to 172.22.0.7:58422
# 2026-02-05 20:24:00,028 INFO scheduler.TaskSetManager: Finished task 1.0 in stage 1.0 (TID 3) in 535 ms on 172.22.0.8 (executor 0) (1/2)
# 2026-02-05 20:24:00,040 INFO scheduler.TaskSetManager: Finished task 0.0 in stage 1.0 (TID 2) in 554 ms on 172.22.0.7 (executor 1) (2/2)
# 2026-02-05 20:24:00,041 INFO scheduler.TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 2026-02-05 20:24:00,043 INFO scheduler.DAGScheduler: ResultStage 1 (collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9) finished in 0.590 s
# 2026-02-05 20:24:00,056 INFO scheduler.DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 2026-02-05 20:24:00,056 INFO scheduler.TaskSchedulerImpl: Killing all running tasks in stage 1: Stage finished
# 2026-02-05 20:24:00,059 INFO scheduler.DAGScheduler: Job 0 finished: collect at /home/jovyan/bigdata/TP/chap8_SPARK/spark_program.py:9, took 34.049223 s
# ('rowcount', 35898)
# 2026-02-05 20:24:00,124 INFO spark.SparkContext: Invoking stop() from shutdown hook
# 2026-02-05 20:24:00,131 INFO server.AbstractConnector: Stopped Spark@b327680{HTTP/1.1, (http/1.1)}{0.0.0.0:4041}
# 2026-02-05 20:24:00,133 INFO ui.SparkUI: Stopped Spark web UI at http://a3b2f2c7c7c5:4041
# 2026-02-05 20:24:00,140 INFO cluster.StandaloneSchedulerBackend: Shutting down all executors
# 2026-02-05 20:24:00,141 INFO cluster.CoarseGrainedSchedulerBackend$DriverEndpoint: Asking each executor to shut down
# 2026-02-05 20:24:00,227 INFO spark.MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 2026-02-05 20:24:00,305 INFO memory.MemoryStore: MemoryStore cleared
# 2026-02-05 20:24:00,306 INFO storage.BlockManager: BlockManager stopped
# 2026-02-05 20:24:00,315 INFO storage.BlockManagerMaster: BlockManagerMaster stopped
# 2026-02-05 20:24:00,324 INFO scheduler.OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 2026-02-05 20:24:00,381 INFO spark.SparkContext: Successfully stopped SparkContext
# 2026-02-05 20:24:00,383 INFO util.ShutdownHookManager: Shutdown hook called
# 2026-02-05 20:24:00,385 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-e5ad6337-d43f-4299-9a40-5bb74ebbb6d1
# 2026-02-05 20:24:00,412 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-2d0b1190-c81f-434e-ae83-361975da9617
# 2026-02-05 20:24:00,434 INFO util.ShutdownHookManager: Deleting directory /tmp/spark-e5ad6337-d43f-4299-9a40-5bb74ebbb6d1/pyspark-0072e4d8-931e-4831-b9aa-0aa3ea0cceb1
